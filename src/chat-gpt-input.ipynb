# %%
import openai,os,sys

# %%
os.getenv('API_KEY')

# %%
openai.organization = "org-tVPg7WQg2Jrk8wWBlVtSDttn"
openai.api_key = "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"

# %%
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7fa60b990770> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
message = "Hi"
messages.append(
        {"role": "user", "content": message},
)
chat_completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages
)
answer = chat_completion.choices[0].message.content
print(f"ChatGPT: {answer}")
messages.append({"role": "assistant", "content": answer})
# Out:
# ChatGPT: Hello! How can I assist you today?

# %%
import json

with open('../datasets/code_xglue/text-to-code/codesearchnet/python/valid.jsonl', 'r') as json_file:
    json_list = list(json_file)

# %%
messages = [
        {"role": "system", "content": "Lets work on code completion task."},
]
answers = []

# %%
messages = [
        {"role": "system", "content": "Lets work on code completion task."},
]

# %%
for json_str in json_list:
    result = json.loads(json_str)
    message = result['docstring_summary']
    print(message)
    messages.append(
        {"role": "user", "content": message},
    )
    chat_completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages
    )
    answer = chat_completion.choices[0].message.content
    #print(f"ChatGPT: {answer}")
    #messages.append({"role": "assistant", "content": answer})
    answers.append({"question": message, "answer": answer})
# Out:
# Helper which expand_dims `is_accepted` then applies tf.where.
# Is event consistent with the given evidence?
# compute similarities in appended files
# Print a status message about the logger.
# Cancel all started queries that have not yet completed
# Fill the entire strip with RGB color tuple
# Generates a set of input record
# Perform an action on the thing.
# Remove memory of state variables set in the command processor
# Split a covariance matrix into block-diagonal marginals of given sizes.
# Hydrate Generated Python AST nodes with line numbers and column offsets
#     if they exist in the node environment.
# Return the entire source file and starting line number for an object.
# Return a dictionary consisting of the key itself
# Read the user configuration
# Compare vectors. Borrowed from A. Parish.
# Retrieve an estimated time correction offset for the given stream.
# This will output the nginx HTTP config string for specific port spec
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(answers)

# %%
df
# Out:
#                                              question  \
# 0   Helper which expand_dims `is_accepted` then ap...
# 1        Is event consistent with the given evidence?
# 2              compute similarities in appended files
# 3            Print a status message about the logger.
# 4   Cancel all started queries that have not yet c...
# 5          Fill the entire strip with RGB color tuple
# 6                     Generates a set of input record
# 7                     Perform an action on the thing.
# 8   Remove memory of state variables set in the co...
# 9   Split a covariance matrix into block-diagonal ...
# 10  Hydrate Generated Python AST nodes with line n...
#
#                                                answer
# 0   Here's the code for the helper function:\n```p...
# 1   Here's an implementation of a helper function ...
# 2   Here's an implementation of a helper function ...
# 3   Here's an implementation of a helper function ...
# ...

# %%
df.to_excel("output.xlsx")

# %%
answers
# Out:
# [{'question': 'Helper which expand_dims `is_accepted` then applies tf.where.',
# ...
