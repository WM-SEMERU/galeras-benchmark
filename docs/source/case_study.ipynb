# %% [markdown]
# # Causal interpretability for Software Engineering

# %% [markdown]
# ## Introduction Interpretability for SE

# %% [markdown]
# What is Interpretability for SE?

# %% [markdown]
# ## Case of study

# %% [markdown]
# ### Correlation analysis??

# %% [markdown]
# ### Causal analysis

# %% [markdown]
# You can download SEMERU datasets at  https://huggingface.co/semeru

# %%
from datasets import load_dataset
import pandas as pd

# %%
d_control = "semeru/Code-code-galeras-prompting-3k-control"

# %%
t1 = "semeru/Code-code-galeras-prompting-3k-treatment-1"

# %%
dataset = "semeru/Code-code-galeras-prompting-3k-treatment-2"

# %%
dataset = load_dataset(dataset, cache_dir="../../datax" )

# %%
dataset.set_format(type='pandas')

# %%
df = dataset['train'][:]

# %% [markdown]
# Stablish confunder variables as $w\in W$

# %%
columns={'vocab_size':'w_vocab_size','n_words':'w_n_words','n_ast_errors':'w_n_ast_errors','ast_levels':'w_ast_levels','n_whitespaces':'w_n_whitespaces','complexity':'w_complexity','nloc':'w_nloc','token_counts':'w_token_counts','n_ast_nodes':'w_n_ast_nodes','ast_errors':'w_ast_errors','n_identifiers':'w_n_identifiers'}
df = df.rename(columns=columns)
df
# Out:
#                                      commit_id  \
# 0     f65417656ba8c59438d832b6e2a431f78d40c21c
# 1     2a05ccdb07cff88e56661dee8a9271859354027f
# 2     4c58179509e6f6047789efb0a95c2b0e20cb6c8f
# 3     3255fa4ebb9fbc1df6bb063c0eb77a0298ca8f72
# 4     b3bc4e734528d3b186c3a38a6e73e106c3555cc7
# ...                                        ...
# 2918  494bd9ef78313436f0424b918f200dab8fc7c20b
# 2919  8198943edd73a363c266633e1aa5b2a9e9c9f526
# 2920  84afc5193d38057e2e2badf9c889ea87d80d8fbf
# 2921  0c20ba744966d23ede67cffd7c5d2e0d01cd0658
# 2922  7d2e77c5f235ca60a2bf3ee02f4f9a8b10b03214
#
#                                                    code          repo  \
# 0     def rolling(self, *args, **kwargs) -> RollingG...        pandas
# 1     def expected_degree_graph(w, seed=None, selflo...      networkx
# 2     def save(self, path):\n        \n        os.ma...        mlflow
# 3     def test_build_group_generic_issue_attachment(...        sentry
# 4     def apply(self, func, mask=None) -> 'ImageProc...  DeepFaceLive
# ...                                                 ...           ...
# 2918  def get_data(conditions, filters):\n\tdata = f...       erpnext
# 2919  def getcoroutinelocals(coroutine):\n    \n    ...        XX-Net
# 2920  def _forward_over_back_hessian(f, params, use_...         keras
# 2921  def predict_proba(self, X):\n        \n       ...  scikit-learn
# 2922  def fetch_jwks(jwks_url) -> Optional[dict]:\n ...        saleor
#
#                                           documentation      id  \
# 0     {'docstring': '
#         Return a rolling group...  167770
# 1     {'docstring': 'Returns a random graph with giv...  176730
# 2     {'docstring': 'Write the evaluation results to...   19151
# 3     {'docstring': 'Test that a generic issue type'...   89933
# 4     {'docstring': '
#         apply your own functio...  179114
# ...                                                 ...     ...
# 2918  {'docstring': '
# 		SELECT
# 			so.transaction_dat...   67430
# 2919  {'docstring': '
#     Get the mapping of corouti...  218391
# 2920  {'docstring': 'Computes the full Hessian matri...  272189
# 2921  {'docstring': 'Probability estimates.
#
#        ...  259605
# 2922  {'docstring': 'Fetch JSON Web Key Sets from a ...   26573
#
#       w_n_ast_errors w_ast_errors  w_vocab_size   d_id  \
# 0                  0                         17  40113
# 1                  0                         97  42064
# 2                  0                         36   2897
# 3                  0                         38  18592
# 4                  0                         34  42906
# ...              ...          ...           ...    ...
# 2918               0                         13  14521
# 2919               0                         33  55277
# 2920               0                         13  80975
# 2921               0                         85  75837
# 2922               0                         59   5027
#
#                                                      T1  ...  \
# 0     {'predicted': {'n_whitespaces': 82, 'n_words':...  ...
# 1     {'predicted': {'n_whitespaces': 555, 'n_words'...  ...
# 2     {'predicted': {'n_whitespaces': 88, 'n_words':...  ...
# 3     {'predicted': {'n_whitespaces': 0, 'n_words': ...  ...
# 4     {'predicted': {'n_whitespaces': 248, 'n_words'...  ...
# ...                                                 ...  ...
# 2918  {'predicted': {'n_whitespaces': 132, 'n_words'...  ...
# 2919  {'predicted': {'n_whitespaces': 87, 'n_words':...  ...
# 2920  {'predicted': {'n_whitespaces': 94, 'n_words':...  ...
# 2921  {'predicted': {'n_whitespaces': 401, 'n_words'...  ...
# 2922  {'predicted': {'n_whitespaces': 99, 'n_words':...  ...
#
#                     file_name  \
# 0                  groupby.py
# 1               degree_seq.py
# 2                     base.py
# 3     test_message_builder.py
# 4           ImageProcessor.py
# ...                       ...
# 2918  sales_order_analysis.py
# 2919               inspect.py
# 2920      forwardprop_test.py
# 2921  _stochastic_gradient.py
# 2922                 utils.py
#
#                                                    path  w_complexity  \
# 0                        pandas/core/groupby/groupby.py             1
# 1                     networkx/generators/degree_seq.py            13
# 2                      mlflow/models/evaluation/base.py             3
# 3     tests/sentry/integrations/slack/test_message_b...             1
# 4                          xlib/image/ImageProcessor.py             3
# ...                                                 ...           ...
# 2918  erpnext/selling/report/sales_order_analysis/sa...             1
# 2919                        python3.10.4/Lib/inspect.py             2
# 2920         keras/integration_test/forwardprop_test.py             1
# 2921       sklearn/linear_model/_stochastic_gradient.py             6
# 2922             saleor/plugins/openid_connect/utils.py             5
#
#       w_n_words w_ast_levels  \
# 0            18            9
# 1           179           17
# 2            49           13
# 3            51           12
# 4            45           13
# ...         ...          ...
# 2918         14           11
# 2919         40            9
# 2920         14            9
# 2921        125           17
# 2922         86           12
#
#                                                    url  \
# 0             https://github.com/pandas-dev/pandas.git
# 1             https://github.com/networkx/networkx.git
# 2                 https://github.com/mlflow/mlflow.git
# 3              https://github.com/getsentry/sentry.git
# 4           https://github.com/iperov/DeepFaceLive.git
# ...                                                ...
# 2918             https://github.com/frappe/erpnext.git
# 2919              https://github.com/XX-net/XX-Net.git
# 2920           https://github.com/keras-team/keras.git
# 2921  https://github.com/scikit-learn/scikit-learn.git
# 2922              https://github.com/saleor/saleor.git
#
#                                                 control language  \
# 0     {'predicted': {'n_whitespaces': 77, 'n_words':...   Python
# 1     {'predicted': {'n_whitespaces': 526, 'n_words'...   Python
# 2     {'predicted': {'n_whitespaces': 0, 'n_words': ...   Python
# 3     {'predicted': {'n_whitespaces': 0, 'n_words': ...   Python
# 4     {'predicted': {'n_whitespaces': 76, 'n_words':...   Python
# ...                                                 ...      ...
# 2918  {'predicted': {'n_whitespaces': 11, 'n_words':...   Python
# 2919  {'predicted': {'n_whitespaces': 39, 'n_words':...   Python
# 2920  {'predicted': {'n_whitespaces': 47, 'n_words':...   Python
# 2921  {'predicted': {'n_whitespaces': 302, 'n_words'...   Python
# 2922  {'predicted': {'n_whitespaces': 38, 'n_words':...   Python
#
#                                                      T2  w_n_whitespaces
# 0     {'predicted': {'n_whitespaces': 45, 'n_words':...              101
# 1     {'predicted': {'n_whitespaces': 328, 'n_words'...              417
# 2     {'predicted': {'n_whitespaces': 40, 'n_words':...              208
# 3     {'predicted': {'n_whitespaces': 120, 'n_words'...              154
# 4     {'predicted': {'n_whitespaces': 62, 'n_words':...              127
# ...                                                 ...              ...
# 2918  {'predicted': {'n_whitespaces': 527, 'n_words'...                5
# 2919  {'predicted': {'n_whitespaces': 73, 'n_words':...              140
# 2920  {'predicted': {'n_whitespaces': 143, 'n_words'...               51
# 2921  {'predicted': {'n_whitespaces': 374, 'n_words'...              603
# 2922  {'predicted': {'n_whitespaces': 198, 'n_words'...              216
#
# [2923 rows x 27 columns]

# %% [markdown]
# Since we have nested data for some columns we will flatten all this information, i.e. flattening the documentation column and its related metrics such as the number of words

# %%
documentation_df = pd.concat([df['id'], df['code'], df['documentation'].apply(pd.Series)], axis=1)
documentation_df
# Out:
#           id                                               code  \
# 0     167770  def rolling(self, *args, **kwargs) -> RollingG...
# 1     176730  def expected_degree_graph(w, seed=None, selflo...
# 2      19151  def save(self, path):\n        \n        os.ma...
# 3      89933  def test_build_group_generic_issue_attachment(...
# 4     179114  def apply(self, func, mask=None) -> 'ImageProc...
# ...      ...                                                ...
# 2918   67430  def get_data(conditions, filters):\n\tdata = f...
# 2919  218391  def getcoroutinelocals(coroutine):\n    \n    ...
# 2920  272189  def _forward_over_back_hessian(f, params, use_...
# 2921  259605  def predict_proba(self, X):\n        \n       ...
# 2922   26573  def fetch_jwks(jwks_url) -> Optional[dict]:\n ...
#
#                                               docstring language  \
# 0     \n        Return a rolling grouper, providing ...       en
# 1     Returns a random graph with given expected deg...       en
# 2     Write the evaluation results to the specified ...       en
# 3     Test that a generic issue type's Slack alert c...       en
# 4     \n        apply your own function on internal ...       en
# ...                                                 ...      ...
# 2918  \n\t\tSELECT\n\t\t\tso.transaction_date as dat...       en
# 2919  \n    Get the mapping of coroutine local varia...       en
# 2920  Computes the full Hessian matrix for the scala...       en
# 2921  Probability estimates.\n\n        This method ...       en
# 2922  Fetch JSON Web Key Sets from a provider.\n\n  ...       en
#
#       n_whitespaces  n_words  vocab_size
# 0                24        9           8
# 1               524      298         173
# 2                 9       10           9
# 3                11       12          12
# 4                79       31          30
# ...             ...      ...         ...
# 2918            112      146         102
# 2919             36       27          22
# 2920            166      105          73
# 2921            339      138          98
# 2922             37       25          24
#
# [2923 rows x 7 columns]

# %%
def flatten_treatment(df,t_name,binary_treatment):
    prefix = "e"
    result = pd.concat([df, df[t_name].apply(pd.Series)], axis=1)
    result = pd.concat([result.drop(['predicted'], axis=1), result['predicted'].apply(pd.Series)], axis=1)
    new_column_names = {'n_whitespaces':prefix+'_n_whitespaces', 'n_words':prefix+'_n_words', 'prediction':prefix+'_prediction', 'vocab_size':prefix+'_vocab_size'}
    result.rename(columns=new_column_names, inplace=True)
    
    
    prefix = "i"
    result = pd.concat([result.drop(['prompt'],axis=1),result['prompt'].apply(pd.Series)], axis=1)
    new_column_names = {'n_whitespaces':prefix+'_n_whitespaces', 'p_n_words':prefix+'_n_words', 'template':prefix+'_template', 'vocab_size':prefix+'_vocab_size'}
    result.rename(columns=new_column_names, inplace=True)
    result['i_binary_treatment'] = binary_treatment
    result['i_treatment'] = t_name
    
    return result

# %% [markdown]
# Create each treatment dataset $t\in T$.
#
# - Control template: "Complete the following python method: ```{Random_cut code}```",
# - Treatment 1 (T1): "Write a Python method that starts with ```{Function Name}``` , I need to complete this function. Remove comments, summary and descriptions.",
# - Treatment 2 (T2): "Remeber you have a Python function named ```{Method Signature}```, the function starts with the following code ```{Random_cut code}```. The description for the function is: ```{docstring}``` remove comments; remove summary; remove description; Return only the code"

# %%
control_df = flatten_treatment(df, "control", False)
T1= flatten_treatment(df, "T1", True)
T2 = flatten_treatment(df, "T2", True)

# %%
T1.columns.tolist()
# Out:
# ['commit_id',
#  'code',
#  'repo',
#  'documentation',
#  'id',
#  'w_n_ast_errors',
#  'w_ast_errors',
#  'w_vocab_size',
#  'd_id',
#  'T1',
#  'commit_message',
#  'fun_name',
#  'w_n_identifiers',
#  'w_nloc',
#  'random_cut',
#  'w_n_ast_nodes',
#  'w_token_counts',
#  'file_name',
#  'path',
#  'w_complexity',
#  'w_n_words',
#  'w_ast_levels',
#  'url',
#  'control',
#  'language',
#  'T2',
#  'w_n_whitespaces',
#  'e_n_whitespaces',
#  'e_n_words',
#  'e_prediction',
#  'e_vocab_size',
#  'i_n_whitespaces',
#  'i_n_words',
#  'i_template',
#  'i_vocab_size',
#  'i_binary_treatment',
#  'i_treatment']

# %%
treatments_df = pd.concat([control_df, T1, T2], join="inner", ignore_index=True)
treatments_df = treatments_df.drop(columns=['control', 'T1', 'T2'])

# %%
treatments_df
# Out:
#                                      commit_id  \
# 0     f65417656ba8c59438d832b6e2a431f78d40c21c
# 1     2a05ccdb07cff88e56661dee8a9271859354027f
# 2     4c58179509e6f6047789efb0a95c2b0e20cb6c8f
# 3     3255fa4ebb9fbc1df6bb063c0eb77a0298ca8f72
# 4     b3bc4e734528d3b186c3a38a6e73e106c3555cc7
# ...                                        ...
# 8764  494bd9ef78313436f0424b918f200dab8fc7c20b
# 8765  8198943edd73a363c266633e1aa5b2a9e9c9f526
# 8766  84afc5193d38057e2e2badf9c889ea87d80d8fbf
# 8767  0c20ba744966d23ede67cffd7c5d2e0d01cd0658
# 8768  7d2e77c5f235ca60a2bf3ee02f4f9a8b10b03214
#
#                                                    code          repo  \
# 0     def rolling(self, *args, **kwargs) -> RollingG...        pandas
# 1     def expected_degree_graph(w, seed=None, selflo...      networkx
# 2     def save(self, path):\n        \n        os.ma...        mlflow
# 3     def test_build_group_generic_issue_attachment(...        sentry
# 4     def apply(self, func, mask=None) -> 'ImageProc...  DeepFaceLive
# ...                                                 ...           ...
# 8764  def get_data(conditions, filters):\n\tdata = f...       erpnext
# 8765  def getcoroutinelocals(coroutine):\n    \n    ...        XX-Net
# 8766  def _forward_over_back_hessian(f, params, use_...         keras
# 8767  def predict_proba(self, X):\n        \n       ...  scikit-learn
# 8768  def fetch_jwks(jwks_url) -> Optional[dict]:\n ...        saleor
#
#                                           documentation      id  \
# 0     {'docstring': '
#         Return a rolling group...  167770
# 1     {'docstring': 'Returns a random graph with giv...  176730
# 2     {'docstring': 'Write the evaluation results to...   19151
# 3     {'docstring': 'Test that a generic issue type'...   89933
# 4     {'docstring': '
#         apply your own functio...  179114
# ...                                                 ...     ...
# 8764  {'docstring': '
# 		SELECT
# 			so.transaction_dat...   67430
# 8765  {'docstring': '
#     Get the mapping of corouti...  218391
# 8766  {'docstring': 'Computes the full Hessian matri...  272189
# 8767  {'docstring': 'Probability estimates.
#
#        ...  259605
# 8768  {'docstring': 'Fetch JSON Web Key Sets from a ...   26573
#
#       w_n_ast_errors w_ast_errors  w_vocab_size   d_id  \
# 0                  0                         17  40113
# 1                  0                         97  42064
# 2                  0                         36   2897
# 3                  0                         38  18592
# 4                  0                         34  42906
# ...              ...          ...           ...    ...
# 8764               0                         13  14521
# 8765               0                         33  55277
# 8766               0                         13  80975
# 8767               0                         85  75837
# 8768               0                         59   5027
#
#                                          commit_message  ... e_n_whitespaces  \
# 0     TYP: more return annotations in core/ (#47618)...  ...              77
# 1     Remove redundant py2 numeric conversions (#566...  ...             526
# 2     Improve evaluation api (#5256)\n\n* init\r\n\r...  ...               0
# 3     feat(integrations): Support generic issue type...  ...               0
# 4                         ImageProcessor.py refactoring  ...              76
# ...                                                 ...  ...             ...
# 8764                      style: format code with black  ...             527
# 8765                      add python 3.10.4 for windows  ...              73
# 8766  Reformatting the codebase with black.\n\nPiper...  ...             143
# 8767  DEP loss "log" in favor of "log loss" in SGDCl...  ...             374
# 8768  Make OIDC plugin public (#9406)\n\n* Make OIDC...  ...             198
#
#       e_n_words                                       e_prediction  \
# 0            72  Certainly! Here's the completed code:\n\n```py...
# 1           332  Here is the completed python method:\n\n```pyt...
# 2             1                                     exist_ok=True)
# 3             1                                           "danger"
# 4            32  ```\n        mask = mask.astype(bool)\n       ...
# ...         ...                                                ...
# 8764        170  Sure! Here's the code without the comments, su...
# 8765         55  Certainly! Here's the code for the `getcorouti...
# 8766         87  Sure! Here's the code for the `_forward_over_b...
# 8767        116  Certainly! Here's the code without comments, s...
# 8768         88  Sure, here is the `fetch_jwks` function withou...
#
#      e_vocab_size  i_n_whitespaces  i_n_words  \
# 0              53               29         16
# 1             182              380        175
# 2               1               23          9
# 3               1              152         50
# 4              28               86         38
# ...           ...              ...        ...
# 8764          122              148        188
# 8765           41              112         83
# 8766           65              243        150
# 8767           78              846        274
# 8768           62              255        129
#
#                                              i_template i_vocab_size  \
# 0        Complete the following python method: ```{}```           16
# 1        Complete the following python method: ```{}```          100
# 2        Complete the following python method: ```{}```            9
# 3        Complete the following python method: ```{}```           38
# 4        Complete the following python method: ```{}```           34
# ...                                                 ...          ...
# 8764  Remeber you have a Python function named {}, t...          134
# 8765  Remeber you have a Python function named {}, t...           65
# 8766  Remeber you have a Python function named {}, t...          104
# 8767  Remeber you have a Python function named {}, t...          180
# 8768  Remeber you have a Python function named {}, t...           89
#
#       i_binary_treatment  i_treatment
# 0                  False      control
# 1                  False      control
# 2                  False      control
# 3                  False      control
# 4                  False      control
# ...                  ...          ...
# 8764                True           T2
# 8765                True           T2
# 8766                True           T2
# 8767                True           T2
# 8768                True           T2
#
# [8769 rows x 34 columns]

# %% [markdown]
# ### Levenshtein Distance

# %%
from Levenshtein import distance as lev
from json import loads, dumps

# %%
def calculate_distance(row):
    return lev(row['code'].strip(), row['e_prediction'].strip())

# %%
treatments_df['y_lev'] = treatments_df.apply(calculate_distance, axis=1)

# %%
treatments_df[['y_lev','i_binary_treatment']].groupby('i_binary_treatment').describe()
# Out:
#                      y_lev                                                    \
#                      count        mean         std  min    25%    50%    75%
# i_binary_treatment
# False               2923.0  591.967157  574.681895  0.0  243.0  464.0  767.5
# True                5846.0  596.623674  579.250708  0.0  272.0  456.0  740.0
#
#
#                         max
# i_binary_treatment
# False               10913.0
# True                12311.0

# %% [markdown]
# Explain metric granularity, in this case we are using sample granularity. CodeBLEU is a dataset level.

# %% [markdown]
# The more input prompt size is close to the GT, the less distance outcome, gt
#
# We expect the following behavior in continues treatments: The more difference lev difference between prompts (i.e. control vs T1, T1 vs T2), the less difference at the potential outcome. We expect a negative correlations or causal effect

# %%
import numpy as np

from dowhy import CausalModel
import dowhy.datasets

# %% [markdown]
# - Binary
# - Continuos
# - Instrumental

# %% [markdown]
# Treatmens are the prompt configuration used as input
#
# - T0, Control template: "Complete the following python method: ```{Random_cut code}```",
# - T1, Treatment 1: "Write a Python method that starts with ```{Function Name}``` , I need to complete this function. Remove comments, summary and descriptions.",
# - T2, Treatment 2: "Remeber you have a Python function named ```{Method Signature}```, the function starts with the following code ```{Random_cut code}```. The description for the function is: ```{docstring}``` remove comments; remove summary; remove description; Return only the code"

# %% [markdown]
# ### Variable description

# %% [markdown]
# Potential outcomes:
#
# Potential outcomes $Y^t$: Levenshtaien distance (code predicion, groundtruth), $t\in T$

# %% [markdown]
# Common causes are the code snippet grountruth metrics
# - w_ast_levels
# - w_n_whitespaces
# - w_complexity
# - w_nloc
# - w_token_counts
# - w_n_ast_nodes
#
# Common causes affect both treatments $T$ and potential outcomes $Y$

# %%
model = CausalModel(
        data = treatments_df,
        treatment = ['i_binary_treatment'],
        outcome = ['y_lev'],
        common_causes = ['w_ast_levels','w_n_whitespaces','w_complexity','w_nloc','w_token_counts','w_n_ast_nodes']
        #common_causes= ['z_nloc']
    )

# %%
identified_estimand = model.identify_effect()

# %% [markdown]
# Instrumental variables: Are the Software Engineering input put prompt metrics
#
# - i_p_n_words
# - i_n_whitespaces
# - i_vocab_size

# %% [markdown]
# Effect modifiers: Are the software engineering potential outcome metrics
# - e_p_n_words
# - e_n_whitespaces
# - e_vocab_size

# %% [markdown]
# - Model parameters
# - Loss prediction
# - Sampling

# %% [markdown]
# Developer experience,
# Demographic info
# machine generated?
# Is a code debug?

# %% [markdown]
# ## Action items

# %% [markdown]
# - [] dependent and independent cofounders
# - [ ] compute cofounders correlation

# %%
treatments_df.shape
# Out:
# (8769, 40)

# %%
causal_estimate_strat = model.estimate_effect(identified_estimand,method_name="backdoor.propensity_score_stratification")

# %%
causal_estimate_matching = model.estimate_effect(
        identified_estimand,
        method_name="backdoor.propensity_score_matching")

# %%
print(causal_estimate_matching)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#           d
# ─────────────────────(E[y_lev|w_nloc,w_ast_levels,w_n_ast_nodes,w_n_whitespace
# d[i_binary_treatment]
#
#
# s,w_token_counts,w_complexity])
#
# Estimand assumption 1, Unconfoundedness: If U→{i_binary_treatment} and U→y_lev then P(y_lev|i_binary_treatment,w_nloc,w_ast_levels,w_n_ast_nodes,w_n_whitespaces,w_token_counts,w_complexity,U) = P(y_lev|i_binary_treatment,w_nloc,w_ast_levels,w_n_ast_nodes,w_n_whitespaces,w_token_counts,w_complexity)
#
# ## Realized estimand
# b: y_lev~i_binary_treatment+w_nloc+w_ast_levels+w_n_ast_nodes+w_n_whitespaces+w_token_counts+w_complexity
# Target units: ate
#
# ## Estimate
# Mean value: 9.218154863724484
